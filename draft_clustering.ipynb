# %% [markdown]
# https://retepelyod2.files.wordpress.com/2024/01/right-primary.pdf
# Peter Doyle Algo <br>
#
# 1. find average gdp from 1990 to 2017, average annual growth of gdp per capita, average primary balance 1990 - 2019 in 2017 international dollars
# 2. find 15 gdp neighbors each side of each country
# 3. take the top 5, drop the top,
# 4. take the bottom 5, drop the bottom
# 5. the 2nd highest is the higher band
# 6. the 2nd lowest is the lower band
# 7. the average of all 8 is the synthete per metric
#
# the 2nd highest map

# %% [markdown]
# Question: <br>
# 1. why does the author omit oil producing countries?
# 2. which primary balance to use? pb , GGCBP_G01_PGDP_PT

# %% [markdown]
# TODO: <br>
# 1. read https://www2.econ.iastate.edu/tesfatsi/Auyang.ComplexSystemsTheories.htm

# %% [markdown]
# Ideas <br>
# - can we do this kind of analysis for every metric?
# - what if instead of droping the top, and bottom we just use the 99th and 1st percentile for each span of 15
# -  what if we form the neighbors in a different way, instead of 15 each way we just use percentiles
# - in general what is the correlation btw primary balance and gdp ?
# - could aim to filter out outliers better
# - relationship between growth rates and primary balance?
# - take k means algo find clusters btw gdp and growth rate then look at the primary balance within those countries
# - divide the data into four quadrants and look for clusters in the quandrants
# - scikit lear has cool functions to deal with imputation
# - this might be a nearest neighbor problem
# - need to fix the colors

# %% [markdown]
# Notes<br>
# - The analytic notion underlying the best peer/synthete analysis applied to Jamaica above is that at each
#     level of GDP per capita there is some optimal balance between borrowing and taxation to deliver the
#     quantum of public goods necessary for development at that level of income.
# - Thus, the analysis applies the best-peer framework illustrated for Jamaica to every country for which
#     data are available for 1990-2019 from the Fall 2023 IMF WEO, and aggregates the results globally.
# - If I want to use clustering https://towardsdatascience.com/common-mistakes-in-cluster-analysis-and-how-to-avoid-them-eb960116d773  need to clean up the data

# %%
import requests
import numpy as np
import polars as pl
import polars.selectors as cs
from dataclasses import dataclass
from typing import Optional

# %%
ALL_COUNTRIES = requests.get(
    "https://www.imf.org/external/datamapper/api/v1/countries"
).json()

# %%
INDICATORS = requests.get(
        "https://www.imf.org/external/datamapper/api/v1/indicators"
    ).json()["indicators"]

# %%
# might want to generalize this any metrics instead of being hard coded
@dataclass
class Country:
    name: str
    abbreviation: str
    average_gdp_per_capita: float
    average_gdp_growth_rate: float
    average_primary_balance: float
    synthete_average_gdp_per_capita: float
    synthete_average_gdp_growth_rate: float
    synthete_average_primary_balance: float
    higher_band: 'Country'
    lower_band: 'Country'

# %%
def get_metric(metric: str) -> dict[str, dict[str,float]]:
    return requests.get(f"https://www.imf.org/external/datamapper/api/v1/{metric}").json()['values'][metric]

# %%
def get_mean_from_imf_dict(imf_dict: dict[str, dict[str,float]]) -> dict[str, float]:
    return {k: sum(v.values()) / len(v) for k, v in imf_dict.items()}

# %%
# likely could generalize this for any metric.
def find_synthete_average(countries: list[Country], position: int) -> tuple[float]:
    return (
        sum([
            countries[position-14].average_gdp_per_capita, 
            countries[position-13].average_gdp_per_capita, 
            countries[position-12].average_gdp_per_capita, 
            countries[position-11].average_gdp_per_capita,
            countries[position+14].average_gdp_per_capita, 
            countries[position+13].average_gdp_per_capita, 
            countries[position+12].average_gdp_per_capita, 
            countries[position+11].average_gdp_per_capita
        ]) / 8), (sum([
            countries[position-14].average_gdp_growth_rate, 
            countries[position-13].average_gdp_growth_rate, 
            countries[position-12].average_gdp_growth_rate, 
            countries[position-11].average_gdp_growth_rate,
            countries[position+14].average_gdp_growth_rate, 
            countries[position+13].average_gdp_growth_rate, 
            countries[position+12].average_gdp_growth_rate, 
            countries[position+11].average_gdp_growth_rate
        ]) / 8),(sum([
            countries[position-14].average_primary_balance, 
            countries[position-13].average_primary_balance, 
            countries[position-12].average_primary_balance, 
            countries[position-11].average_primary_balance,
            countries[position+14].average_primary_balance, 
            countries[position+13].average_primary_balance, 
            countries[position+12].average_primary_balance, 
            countries[position+11].average_primary_balance
        ]) / 8)

# %%
gdp_per_capita = get_metric('PPPPC')

# %%
average_gdp_per_capita = dict(sorted(get_mean_from_imf_dict(gdp_per_capita).items(),key =lambda x:x[1])) # sorted always returns a list

# %%
# since the gdps are sorted, we use this list to establish the rank in gdp 
countries = [
    Country(
        name= ALL_COUNTRIES['countries'][abbreviation]['label'],
        abbreviation=abbreviation,
        average_gdp_per_capita=average_gdp_per_capita,
        average_gdp_growth_rate=None,
        average_primary_balance=None,
        synthete_average_gdp_per_capita=None,
        synthete_average_gdp_growth_rate=None,
        synthete_average_primary_balance=None,
        higher_band=None,
        lower_band=None
    ) for abbreviation, average_gdp_per_capita in average_gdp_per_capita.items() if abbreviation in ALL_COUNTRIES['countries']]

# %%
gdp_growth_rate = get_metric('NGDP_RPCH')
primary_balance = get_metric('GGXCNL_NGDP')
average_gdp_growth_rate = get_mean_from_imf_dict(gdp_growth_rate)
average_primary_balance = get_mean_from_imf_dict(primary_balance)

# %%
for country in countries:
    country.average_gdp_growth_rate = average_gdp_growth_rate[country.abbreviation]
    country.average_primary_balance = average_primary_balance[country.abbreviation]

# %%
for i,country in enumerate(countries):
    if (i - 14) < 0 or (i + 14) >= len(countries):
        continue
    country.higher_band = countries[i+14]
    country.lower_band = countries[i-14]
    country.synthete_average_gdp_per_capita, country.synthete_average_gdp_growth_rate,  country.synthete_average_primary_balance = find_synthete_average(countries, i)

# %%
countries
# Out:
# [Country(name='Burundi', abbreviation='BDI', average_gdp_per_capita=632.3505306122448, average_gdp_growth_rate=2.4387755102040813, average_primary_balance=-5.087179487179488, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Mozambique', abbreviation='MOZ', average_gdp_per_capita=806.6956122448981, average_gdp_growth_rate=5.210204081632654, average_primary_balance=-3.951020408163265, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Central African Republic', abbreviation='CAF', average_gdp_per_capita=824.6955714285715, average_gdp_growth_rate=1.5408163265306116, average_primary_balance=-2.2170731707317075, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='South Sudan, Republic of', abbreviation='SSD', average_gdp_per_capita=867.2927222222222, average_gdp_growth_rate=-0.7999999999999996, average_primary_balance=-2.266666666666668, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Congo, Dem. Rep. of the', abbreviation='COD', average_gdp_per_capita=872.7772244897958, average_gdp_growth_rate=2.1469387755102045, average_primary_balance=-0.8848484848484848, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Niger', abbreviation='NER', average_gdp_per_capita=1031.0258979591833, average_gdp_growth_rate=3.7244897959183674, average_primary_balance=-2.1029411764705883, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Malawi', abbreviation='MWI', average_gdp_per_capita=1066.9080408163265, average_gdp_growth_rate=3.553061224489797, average_primary_balance=-4.225925925925925, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Chad', abbreviation='TCD', average_gdp_per_capita=1228.240306122449, average_gdp_growth_rate=4.300000000000002, average_primary_balance=-1.023529411764706, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Sierra Leone', abbreviation='SLE', average_gdp_per_capita=1252.3611632653062, average_gdp_growth_rate=2.142857142857143, average_primary_balance=-3.6206896551724133, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Liberia', abbreviation='LBR', average_gdp_per_capita=1337.3551379310343, average_gdp_growth_rate=3.4214285714285717, average_primary_balance=-2.382758620689655, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Burkina Faso', abbreviation='BFA', average_gdp_per_capita=1352.2283061224493, average_gdp_growth_rate=4.961224489795919, average_primary_balance=-3.397727272727273, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Eritrea', abbreviation='ERI', average_gdp_per_capita=1377.4761785714286, average_gdp_growth_rate=3.77037037037037, average_primary_balance=-12.15357142857143, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Rwanda', abbreviation='RWA', average_gdp_per_capita=1389.9057142857139, average_gdp_growth_rate=5.0081632653061225, average_primary_balance=-3.097297297297297, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Ethiopia', abbreviation='ETH', average_gdp_per_capita=1424.2193265306123, average_gdp_growth_rate=5.928571428571429, average_primary_balance=-3.6163265306122447, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Madagascar', abbreviation='MDG', average_gdp_per_capita=1460.344632653061, average_gdp_growth_rate=2.2673469387755105, average_primary_balance=-3.7163265306122453, synthete_average_gdp_per_capita=1419.0671096655328, synthete_average_gdp_growth_rate=2.7630504833512353, synthete_average_primary_balance=-2.640087571452492, higher_band=Country(name='Comoros', abbreviation='COM', average_gdp_per_capita=2187.058, average_gdp_growth_rate=2.86938775510204, average_primary_balance=-1.5511111111111107, synthete_average_gdp_per_capita=2218.879359564515, synthete_average_gdp_growth_rate=3.070303426248548, synthete_average_primary_balance=-4.408039326997026, higher_band=Country(name='Micronesia, Fed. States of', abbreviation='FSM', average_gdp_per_capita=3027.962852941176, average_gdp_growth_rate=0.3666666666666667, average_primary_balance=1.5911764705882356, synthete_average_gdp_per_capita=3160.787641947722, synthete_average_gdp_growth_rate=4.014808449695668, synthete_average_primary_balance=-2.9433107392910802, higher_band=Country(name="Côte d'Ivoire", abbreviation='CIV', average_gdp_per_capita=4100.703122448978, average_gdp_growth_rate=3.2979591836734694, average_primary_balance=-2.2, synthete_average_gdp_per_capita=4402.221467052143, synthete_average_gdp_growth_rate=3.7618027210884355, synthete_average_primary_balance=-2.842196867161547, higher_band=Country(name='Morocco', abbreviation='MAR', average_gdp_per_capita=5795.235408163266, average_gdp_growth_rate=3.583673469387755, average_primary_balance=-2.9666666666666672, synthete_average_gdp_per_capita=6117.36427936944, synthete_average_gdp_growth_rate=3.0803604994629437, synthete_average_primary_balance=-2.7149566906261953, higher_band=Country(name='Namibia', abbreviation='NAM', average_gdp_per_capita=8208.72041025641, average_gdp_growth_rate=3.144736842105262, average_primary_balance=-3.1435897435897435, synthete_average_gdp_per_capita=7885.525954012686, synthete_average_gdp_growth_rate=3.826944099711957, synthete_average_primary_balance=-2.5853912692106085, higher_band=Country(name='Colombia', abbreviation='COL', average_gdp_per_capita=10144.931897959184, average_gdp_growth_rate=3.393877551020409, average_primary_balance=-2.4063829787234043, synthete_average_gdp_per_capita=10083.495500646848, synthete_average_gdp_growth_rate=3.6686518291527137, synthete_average_primary_balance=-3.404779021231364, higher_band=Country(name='Brazil', abbreviation='BRA', average_gdp_per_capita=12006.75367346939, average_gdp_growth_rate=2.293877551020408, average_primary_balance=-4.821428571428571, synthete_average_gdp_per_capita=12744.340117866554, synthete_average_gdp_growth_rate=3.2864558614143338, synthete_average_primary_balance=-3.745431794452796, higher_band=Country(name='Argentina', abbreviation='ARG', average_gdp_per_capita=15454.893755102043, average_gdp_growth_rate=1.8673469387755104, average_primary_balance=-2.358333333333333, synthete_average_gdp_per_capita=15985.720318956006, synthete_average_gdp_growth_rate=3.1932539682539685, synthete_average_primary_balance=-2.139287076697187, higher_band=Country(name='Trinidad and Tobago', abbreviation='TTO', average_gdp_per_capita=20151.115163265305, average_gdp_growth_rate=2.16326530612245, average_primary_balance=-2.0682926829268293, synthete_average_gdp_per_capita=21224.154463293653, synthete_average_gdp_growth_rate=3.236836734693878, synthete_average_primary_balance=-1.594698037831544, higher_band=Country(name='Israel', abbreviation='ISR', average_gdp_per_capita=27785.235142857146, average_gdp_growth_rate=4.1204081632653065, average_primary_balance=-3.2931034482758625, synthete_average_gdp_per_capita=27056.856203296702, synthete_average_gdp_growth_rate=2.914782491944146, synthete_average_primary_balance=-2.499717594059654, higher_band=Country(name='Finland', abbreviation='FIN', average_gdp_per_capita=34185.22295918367, average_gdp_growth_rate=1.979591836734693, average_primary_balance=0.11632653061224499, synthete_average_gdp_per_capi ...
#  Country(name='Mali', abbreviation='MLI', average_gdp_per_capita=1501.695836734694, average_gdp_growth_rate=3.9816326530612245, average_primary_balance=-2.062068965517241, synthete_average_gdp_per_capita=1487.0062943594105, synthete_average_gdp_growth_rate=2.6867346938775514, synthete_average_primary_balance=-2.2488694720231854, higher_band=Country(name='Nepal', abbreviation='NPL', average_gdp_per_capita=2234.4861836734694, average_gdp_growth_rate=4.391836734693877, average_primary_balance=-2.0275862068965513, synthete_average_gdp_per_capita=2273.912719258393, synthete_average_gdp_growth_rate=3.0588238344118137, synthete_average_primary_balance=-4.867551616329205, higher_band=Country(name='Sudan', abbreviation='SDN', average_gdp_per_capita=3084.5965510204082, average_gdp_growth_rate=2.6204081632653056, average_primary_balance=-4.348717948717949, synthete_average_gdp_per_capita=3224.1033128660893, synthete_average_gdp_growth_rate=3.404094163981382, synthete_average_primary_balance=-1.9578650668656064, higher_band=Country(name='Tonga', abbreviation='TON', average_gdp_per_capita=4137.3835714285715, average_gdp_growth_rate=3.248979591836735, average_primary_balance=-0.1600000000000002, synthete_average_gdp_per_capita=4556.9280414190525, synthete_average_gdp_growth_rate=4.630303651866152, synthete_average_primary_balance=-2.9044831921645216, higher_band=Country(name='Uzbekistan', abbreviation='UZB', average_gdp_per_capita=5929.468162162163, average_gdp_growth_rate=4.705405405405405, average_primary_balance=-1.1729729729729725, synthete_average_gdp_per_capita=6199.67600436944, synthete_average_gdp_growth_rate=3.155262960447337, synthete_average_primary_balance=-2.547135683366667, higher_band=Country(name='Peru', abbreviation='PER', average_gdp_per_capita=8328.034489795918, average_gdp_growth_rate=3.159183673469387, average_primary_balance=-0.9413793103448275, synthete_average_gdp_per_capita=8027.969503713601, synthete_average_gdp_growth_rate=3.869546140528284, synthete_average_primary_balance=-2.3749713253710025, higher_band=Country(name='Kosovo', abbreviation='UVK', average_gdp_per_capita=10340.16872413793, average_gdp_growth_rate=3.8857142857142857, average_primary_balance=-1.206896551724138, synthete_average_gdp_per_capita=10224.480868843242, synthete_average_gdp_growth_rate=3.9591892590369477, synthete_average_primary_balance=-2.649975582537965, higher_band=Country(name='Turkmenistan', abbreviation='TKM', average_gdp_per_capita=12333.812270270271, average_gdp_growth_rate=4.769444444444444, average_primary_balance=0.9406249999999996, synthete_average_gdp_per_capita=12897.82493439448, synthete_average_gdp_growth_rate=3.0335893200609494, synthete_average_primary_balance=-3.9540090741583, higher_band=Country(name='Bulgaria', abbreviation='BGR', average_gdp_per_capita=15465.563938775509, average_gdp_growth_rate=1.4551020408163264, average_primary_balance=-0.835483870967742, synthete_average_gdp_per_capita=16362.925534473248, synthete_average_gdp_growth_rate=3.1648100907029475, synthete_average_primary_balance=-1.9447124519755037, higher_band=Country(name='Poland', abbreviation='POL', average_gdp_per_capita=20202.62108163265, average_gdp_growth_rate=2.6469387755102045, average_primary_balance=-4.0323529411764705, synthete_average_gdp_per_capita=21574.883188197156, synthete_average_gdp_growth_rate=3.419303369441619, synthete_average_primary_balance=-1.3060549512865816, higher_band=Country(name='Lithuania', abbreviation='LTU', average_gdp_per_capita=28263.484352941177, average_gdp_growth_rate=3.754545454545454, average_primary_balance=-2.570588235294117, synthete_average_gdp_per_capita=27431.3415527865, synthete_average_gdp_growth_rate=3.2180988184747585, synthete_average_primary_balance=-2.208134713252546, higher_band=Country(name='Oman', abbreviation='OMN', average_gdp_per_capita=34223.00342857142, average_gdp_growth_rate=4.573469387755102, average_primary_balance=1.1871794871794876, synthete_average_gdp_per_capita=36769.52196503602,  ...
#  Country(name='Guinea-Bissau', abbreviation='GNB', average_gdp_per_capita=1565.7453673469386, average_gdp_growth_rate=3.3166666666666664, average_primary_balance=-2.997368421052632, synthete_average_gdp_per_capita=1547.7898020124717, synthete_average_gdp_growth_rate=2.7010204081632656, synthete_average_primary_balance=-1.9711490417458113, higher_band=Country(name='Benin', abbreviation='BEN', average_gdp_per_capita=2313.229918367347, average_gdp_growth_rate=4.257142857142858, average_primary_balance=-2.0500000000000007, synthete_average_gdp_per_capita=2350.6373072685974, synthete_average_gdp_growth_rate=2.5165391156462587, synthete_average_primary_balance=-4.776173803281757, higher_band=Country(name='Kenya', abbreviation='KEN', average_gdp_per_capita=3225.405020408163, average_gdp_growth_rate=3.9836734693877554, average_primary_balance=-3.510638297872341, synthete_average_gdp_per_capita=3267.4787286824157, synthete_average_gdp_growth_rate=2.8123212047977084, synthete_average_primary_balance=-1.634815966415831, higher_band=Country(name='Tuvalu', abbreviation='TUV', average_gdp_per_capita=4160.251, average_gdp_growth_rate=2.2392857142857148, average_primary_balance=-1.0800000000000012, synthete_average_gdp_per_capita=4671.13777611293, synthete_average_gdp_growth_rate=5.16652814166207, synthete_average_primary_balance=-3.1139525472142333, higher_band=Country(name='Bhutan', abbreviation='BTN', average_gdp_per_capita=5979.449693877552, average_gdp_growth_rate=6.46122448979592, average_primary_balance=-3.0541666666666667, synthete_average_gdp_per_capita=6305.386294494865, synthete_average_gdp_growth_rate=3.1940384706514187, synthete_average_primary_balance=-2.1742219304529145, higher_band=Country(name='Dominica', abbreviation='DMA', average_gdp_per_capita=8373.274729166667, average_gdp_growth_rate=2.6714285714285717, average_primary_balance=-2.928205128205128, synthete_average_gdp_per_capita=8155.60713507111, synthete_average_gdp_growth_rate=3.6051376364499292, synthete_average_primary_balance=-2.9585944589941366, higher_band=Country(name='Grenada', abbreviation='GRD', average_gdp_per_capita=10360.365387755102, average_gdp_growth_rate=3.318367346938775, average_primary_balance=-2.069230769230769, synthete_average_gdp_per_capita=10388.284562777482, synthete_average_gdp_growth_rate=4.4831178304655195, synthete_average_primary_balance=-2.969272891730209, higher_band=Country(name='Costa Rica', abbreviation='CRI', average_gdp_per_capita=12693.349265306124, average_gdp_growth_rate=3.6775510204081625, average_primary_balance=-3.64102564102564, synthete_average_gdp_per_capita=13004.363435713973, synthete_average_gdp_growth_rate=2.153997483326256, synthete_average_primary_balance=-3.628904078579167, higher_band=Country(name='Uruguay', abbreviation='URY', average_gdp_per_capita=15565.668102040816, average_gdp_growth_rate=2.2346938775510217, average_primary_balance=-2.05, synthete_average_gdp_per_capita=16580.964260044973, synthete_average_gdp_growth_rate=3.1212018140589572, synthete_average_primary_balance=-2.9163815670039934, higher_band=Country(name='Guyana', abbreviation='GUY', average_gdp_per_capita=20301.482, average_gdp_growth_rate=6.9346938775510205, average_primary_balance=-3.3125, synthete_average_gdp_per_capita=22089.991361666544, synthete_average_gdp_growth_rate=3.2835890837273327, synthete_average_primary_balance=-2.1301833929858414, higher_band=Country(name='Spain', abbreviation='ESP', average_gdp_per_capita=28371.807, average_gdp_growth_rate=2.1265306122448977, average_primary_balance=-4.277551020408164, synthete_average_gdp_per_capita=27887.92027171728, synthete_average_gdp_growth_rate=3.0363315282253254, synthete_average_primary_balance=-1.8556047496542039, higher_band=Country(name='Aruba', abbreviation='ABW', average_gdp_per_capita=34405.556767441856, average_gdp_growth_rate=3.390476190476189, average_primary_balance=-2.5, synthete_average_gdp_per_capita=38199.41753061225, synthete_average_gdp_growth_rate=2.810459183673469, sy ...
#  Country(name='Kiribati', abbreviation='KIR', average_gdp_per_capita=1576.439306122449, average_gdp_growth_rate=1.4693877551020402, average_primary_balance=-1.3230769230769222, synthete_average_gdp_per_capita=1617.0279177958819, synthete_average_gdp_growth_rate=2.6420238095238093, synthete_average_primary_balance=-2.2209266131565832, higher_band=Country(name='Zimbabwe', abbreviation='ZWE', average_gdp_per_capita=2363.44535483871, average_gdp_growth_rate=0.993333333333333, average_primary_balance=-2.6583333333333345, synthete_average_gdp_per_capita=2450.6461993450607, synthete_average_gdp_growth_rate=2.9267036814725893, synthete_average_primary_balance=-2.0262867368252935, higher_band=Country(name='Myanmar', abbreviation='MMR', average_gdp_per_capita=3475.9765161290325, average_gdp_growth_rate=6.4399999999999995, average_primary_balance=-4.216129032258064, synthete_average_gdp_per_capita=3320.655989278962, synthete_average_gdp_growth_rate=2.602251387397064, synthete_average_primary_balance=-1.9020549774048416, higher_band=Country(name='Djibouti', abbreviation='DJI', average_gdp_per_capita=4262.19564102564, average_gdp_growth_rate=2.9894736842105267, average_primary_balance=-3.6461538461538465, synthete_average_gdp_per_capita=4776.557334786399, synthete_average_gdp_growth_rate=4.663722019213091, synthete_average_primary_balance=-3.4755785429964576, higher_band=Country(name='El Salvador', abbreviation='SLV', average_gdp_per_capita=6033.476489795918, average_gdp_growth_rate=1.7020408163265304, average_primary_balance=-3.6153846153846145, synthete_average_gdp_per_capita=6409.973353168334, synthete_average_gdp_growth_rate=3.5676991849371325, synthete_average_primary_balance=-2.257515435354875, higher_band=Country(name='Mongolia', abbreviation='MNG', average_gdp_per_capita=8516.399, average_gdp_growth_rate=4.534693877551021, average_primary_balance=-4.889583333333333, synthete_average_gdp_per_capita=8283.238029767359, synthete_average_gdp_growth_rate=3.2084302325581397, synthete_average_primary_balance=-4.076758809524558, higher_band=Country(name='Lebanon', abbreviation='LBN', average_gdp_per_capita=10446.465953488374, average_gdp_growth_rate=2.065116279069768, average_primary_balance=-13.096969696969694, synthete_average_gdp_per_capita=10561.909357211804, synthete_average_gdp_growth_rate=3.9150864512471655, synthete_average_primary_balance=-3.1457644150463295, higher_band=Country(name='North Macedonia ', abbreviation='MKD', average_gdp_per_capita=12828.274648648649, average_gdp_growth_rate=2.1777777777777776, average_primary_balance=-2.5125, synthete_average_gdp_per_capita=13111.907693367037, synthete_average_gdp_growth_rate=2.3404770751629913, synthete_average_primary_balance=-3.291345803520892, higher_band=Country(name='Chile', abbreviation='CHL', average_gdp_per_capita=15758.624020408162, average_gdp_growth_rate=3.8734693877551027, average_primary_balance=0.1205128205128207, synthete_average_gdp_per_capita=16876.604948035554, synthete_average_gdp_growth_rate=2.422974101921471, synthete_average_primary_balance=-2.4469198114850856, higher_band=Country(name='Russian Federation', abbreviation='RUS', average_gdp_per_capita=21378.44276923077, average_gdp_growth_rate=0.963157894736842, average_primary_balance=0.041935483870967585, synthete_average_gdp_per_capita=22530.13576940464, synthete_average_gdp_growth_rate=3.4950176551559045, synthete_average_primary_balance=-2.4654115226992652, higher_band=Country(name='Cyprus', abbreviation='CYP', average_gdp_per_capita=28882.759714285716, average_gdp_growth_rate=3.8775510204081627, average_primary_balance=-1.7000000000000006, synthete_average_gdp_per_capita=28482.75251916626, synthete_average_gdp_growth_rate=2.3671988751641004, synthete_average_primary_balance=-2.1012361272052242, higher_band=Country(name='Canada', abbreviation='CAN', average_gdp_per_capita=35621.081755102045, average_gdp_growth_rate=2.240816326530612, average_primary_balance=-2.7061224489795923, synthete_average_gdp_per_capit ...
#  Country(name='Togo', abbreviation='TGO', average_gdp_per_capita=1667.2778571428573, average_gdp_growth_rate=3.022448979591837, average_primary_balance=-3.1574999999999998, synthete_average_gdp_per_capita=1698.8887560895328, synthete_average_gdp_growth_rate=3.0285034013605445, synthete_average_primary_balance=-2.075942442404949, higher_band=Country(name='Haiti', abbreviation='HTI', average_gdp_per_capita=2480.9971224489796, average_gdp_growth_rate=0.8612244897959183, average_primary_balance=-1.634375, synthete_average_gdp_per_capita=2547.9402279314954, synthete_average_gdp_growth_rate=4.054222814125651, synthete_average_primary_balance=-2.751045991488697, higher_band=Country(name='Bangladesh', abbreviation='BGD', average_gdp_per_capita=3568.5857755102047, average_gdp_growth_rate=5.354166666666667, average_primary_balance=-3.161224489795918, synthete_average_gdp_per_capita=3385.107958189429, synthete_average_gdp_growth_rate=3.005283100082138, synthete_average_primary_balance=-2.2471555521174857, higher_band=Country(name='West Bank and Gaza', abbreviation='WBG', average_gdp_per_capita=4400.763371428572, average_gdp_growth_rate=4.044117647058823, average_primary_balance=-3.5949999999999998, synthete_average_gdp_per_capita=4847.558984555985, synthete_average_gdp_growth_rate=4.208977121253906, synthete_average_primary_balance=-3.0181608302537923, higher_band=Country(name='Guatemala', abbreviation='GTM', average_gdp_per_capita=6079.937285714287, average_gdp_growth_rate=3.0306122448979593, average_primary_balance=-1.9029411764705884, synthete_average_gdp_per_capita=6536.1280952274665, synthete_average_gdp_growth_rate=4.167249399759903, synthete_average_primary_balance=-1.7276070977887972, higher_band=Country(name="China, People's Republic of", abbreviation='CHN', average_gdp_per_capita=8637.089816326528, average_gdp_growth_rate=8.479591836734693, average_primary_balance=-2.5297872340425527, synthete_average_gdp_per_capita=8506.49360905039, synthete_average_gdp_growth_rate=3.403522874878225, synthete_average_primary_balance=-3.9456733326318223, higher_band=Country(name='Georgia', abbreviation='GEO', average_gdp_per_capita=10620.56555263158, average_gdp_growth_rate=2.0342105263157895, average_primary_balance=-2.1882352941176464, synthete_average_gdp_per_capita=10792.344824048538, synthete_average_gdp_growth_rate=3.7788619614512466, synthete_average_primary_balance=-2.225346848981442, higher_band=Country(name='Iran', abbreviation='IRN', average_gdp_per_capita=13339.697591836735, average_gdp_growth_rate=2.4122448979591833, average_primary_balance=-3.0435897435897434, synthete_average_gdp_per_capita=13280.480416814918, synthete_average_gdp_growth_rate=2.906761503412911, synthete_average_primary_balance=-1.6704099362272662, higher_band=Country(name='Serbia', abbreviation='SRB', average_gdp_per_capita=16162.1093125, average_gdp_growth_rate=3.1096774193548384, average_primary_balance=-2.03448275862069, synthete_average_gdp_per_capita=17235.63537003329, synthete_average_gdp_growth_rate=2.2517722878625133, synthete_average_primary_balance=-2.6846401987358646, higher_band=Country(name='Hungary', abbreviation='HUN', average_gdp_per_capita=21885.381877551023, average_gdp_growth_rate=1.814285714285714, average_primary_balance=-4.641176470588235, synthete_average_gdp_per_capita=22912.3861520577, synthete_average_gdp_growth_rate=3.3174666347477406, synthete_average_primary_balance=-2.652409122800314, higher_band=Country(name='Bahamas, The', abbreviation='BHS', average_gdp_per_capita=28899.668204081645, average_gdp_growth_rate=1.9571428571428573, average_primary_balance=-2.4999999999999996, synthete_average_gdp_per_capita=29080.89697837645, synthete_average_gdp_growth_rate=2.67047193877551, synthete_average_primary_balance=-2.7867324584487174, higher_band=Country(name='Australia', abbreviation='AUS', average_gdp_per_capita=36266.79051020408, average_gdp_growth_rate=2.9244897959183676, average_primary_balance=-1.8121951219512198, synthete_average_gdp_ ...
#  Country(name='Solomon Islands', abbreviation='SLB', average_gdp_per_capita=1758.1320204081637, average_gdp_growth_rate=2.2816326530612248, average_primary_balance=-0.7204081632653063, synthete_average_gdp_per_capita=1779.119439763002, synthete_average_gdp_growth_rate=2.9014625850340137, synthete_average_primary_balance=-2.3495286606594576, higher_band=Country(name='Papua New Guinea', abbreviation='PNG', average_gdp_per_capita=2496.747714285714, average_gdp_growth_rate=3.379591836734693, average_primary_balance=-1.4804347826086952, synthete_average_gdp_per_capita=2647.1916896661896, synthete_average_gdp_growth_rate=4.551161589635854, synthete_average_primary_balance=-2.694287276362971, higher_band=Country(name='Ghana', abbreviation='GHA', average_gdp_per_capita=3693.0661020408165, average_gdp_growth_rate=4.4755102040816315, average_primary_balance=-4.76530612244898, synthete_average_gdp_per_capita=3457.8294658424907, synthete_average_gdp_growth_rate=3.336915753143362, synthete_average_primary_balance=-1.5944757095103799, higher_band=Country(name='Angola', abbreviation='AGO', average_gdp_per_capita=4592.495183673469, average_gdp_growth_rate=4.687755102040818, average_primary_balance=0.07878787878787873, synthete_average_gdp_per_capita=4913.7055144242495, synthete_average_gdp_growth_rate=3.8768213099193165, synthete_average_primary_balance=-3.884496664341727, higher_band=Country(name='Sri Lanka', abbreviation='LKA', average_gdp_per_capita=6224.045744186046, average_gdp_growth_rate=4.602325581395349, average_primary_balance=-6.806060606060605, synthete_average_gdp_per_capita=6638.1000156356295, synthete_average_gdp_growth_rate=4.2617346938775515, synthete_average_primary_balance=-2.4977583447099794, higher_band=Country(name='Albania', abbreviation='ALB', average_gdp_per_capita=8662.920020408163, average_gdp_growth_rate=2.9530612244897965, average_primary_balance=-4.671874999999999, synthete_average_gdp_per_capita=8757.459732818863, synthete_average_gdp_growth_rate=3.4484208340618987, synthete_average_primary_balance=-4.218090647258823, higher_band=Country(name='South Africa', abbreviation='ZAF', average_gdp_per_capita=10698.86542857143, average_gdp_growth_rate=2.0224489795918377, average_primary_balance=-3.758620689655173, synthete_average_gdp_per_capita=10972.03435443273, synthete_average_gdp_growth_rate=2.834722222222222, synthete_average_primary_balance=-3.310804133828687, higher_band=Country(name='Suriname', abbreviation='SUR', average_gdp_per_capita=13372.278615384615, average_gdp_growth_rate=1.0775510204081635, average_primary_balance=-2.9794871794871787, synthete_average_gdp_per_capita=13623.433937021686, synthete_average_gdp_growth_rate=3.4874341672152736, synthete_average_primary_balance=-1.7425650886108, higher_band=Country(name='Saint Kitts and Nevis', abbreviation='KNA', average_gdp_per_capita=17465.79479591837, average_gdp_growth_rate=3.6122448979591826, average_primary_balance=-2.124489795918367, synthete_average_gdp_per_capita=17620.16846758905, synthete_average_gdp_growth_rate=2.2651707234778944, synthete_average_primary_balance=-2.409378353923498, higher_band=Country(name='Latvia', abbreviation='LVA', average_gdp_per_capita=22606.03735135135, average_gdp_growth_rate=2.947222222222223, average_primary_balance=-2.07741935483871, synthete_average_gdp_per_capita=23281.551272959186, synthete_average_gdp_growth_rate=3.6441326530612246, synthete_average_primary_balance=-2.7777920478536244, higher_band=Country(name='Malta', abbreviation='MLT', average_gdp_per_capita=29052.41557142857, average_gdp_growth_rate=4.1000000000000005, average_primary_balance=-3.251724137931035, synthete_average_gdp_per_capita=29668.58496817237, synthete_average_gdp_growth_rate=2.3646045918367347, synthete_average_primary_balance=-3.5316498976963313, higher_band=Country(name='Belgium', abbreviation='BEL', average_gdp_per_capita=36390.89940816326, average_gdp_growth_rate=1.8061224489795917, average_primary_balance=-4.987755102040817, synthete_ave ...
#  Country(name='Somalia', abbreviation='SOM', average_gdp_per_capita=1789.3794705882353, average_gdp_growth_rate=3.2294117647058824, average_primary_balance=-0.525, synthete_average_gdp_per_capita=1848.697403432953, synthete_average_gdp_growth_rate=2.8074574829931978, synthete_average_primary_balance=-2.4228986983296985, higher_band=Country(name='Senegal', abbreviation='SEN', average_gdp_per_capita=2563.524387755102, average_gdp_growth_rate=3.8081632653061224, average_primary_balance=-2.357142857142857, synthete_average_gdp_per_capita=2725.002901531705, synthete_average_gdp_growth_rate=4.869784038615445, synthete_average_primary_balance=-2.9780934345327306, higher_band=Country(name='Pakistan', abbreviation='PAK', average_gdp_per_capita=3737.200530612245, average_gdp_growth_rate=4.5877551020408145, average_primary_balance=-4.852777777777779, synthete_average_gdp_per_capita=3532.7207964285712, synthete_average_gdp_growth_rate=3.287147358943577, synthete_average_primary_balance=-1.6766809770689082, higher_band=Country(name='Congo, Republic of ', abbreviation='COG', average_gdp_per_capita=4597.904, average_gdp_growth_rate=3.310204081632653, average_primary_balance=1.005, synthete_average_gdp_per_capita=5013.920720259708, synthete_average_gdp_growth_rate=3.157515845798184, synthete_average_primary_balance=-2.8571662009063528, higher_band=Country(name='Eswatini', abbreviation='SWZ', average_gdp_per_capita=6636.5127551020405, average_gdp_growth_rate=3.669387755102041, average_primary_balance=-1.5102040816326527, synthete_average_gdp_per_capita=6733.855216810571, synthete_average_gdp_growth_rate=4.09452873254565, synthete_average_primary_balance=-2.5356487561003904, higher_band=Country(name='Fiji', abbreviation='FJI', average_gdp_per_capita=8816.676163265307, average_gdp_growth_rate=2.434693877551021, average_primary_balance=-3.0405405405405403, synthete_average_gdp_per_capita=9037.227155816014, synthete_average_gdp_growth_rate=3.5110127894487055, synthete_average_primary_balance=-1.3141337708019465, higher_band=Country(name='Saint Lucia', abbreviation='LCA', average_gdp_per_capita=10884.614795918369, average_gdp_growth_rate=3.1714285714285735, average_primary_balance=-2.1636363636363636, synthete_average_gdp_per_capita=11125.186370841995, synthete_average_gdp_growth_rate=2.2023108366153474, synthete_average_primary_balance=-2.7821012175660287, higher_band=Country(name='Barbados', abbreviation='BRB', average_gdp_per_capita=13438.927714285714, average_gdp_growth_rate=1.0081632653061223, average_primary_balance=-1.6685714285714286, synthete_average_gdp_per_capita=13965.25027885842, synthete_average_gdp_growth_rate=3.9680464121132326, synthete_average_primary_balance=-1.8231080953526215, higher_band=Country(name='Antigua and Barbuda', abbreviation='ATG', average_gdp_per_capita=17551.27181632653, average_gdp_growth_rate=3.485714285714287, average_primary_balance=-3.8435897435897437, synthete_average_gdp_per_capita=18115.296084543526, synthete_average_gdp_growth_rate=1.895527866335037, synthete_average_primary_balance=-2.917223728479156, higher_band=Country(name='Greece', abbreviation='GRC', average_gdp_per_capita=23557.29324489796, average_gdp_growth_rate=1.0285714285714285, average_primary_balance=-6.230612244897959, synthete_average_gdp_per_capita=23514.620767857145, synthete_average_gdp_growth_rate=3.5028061224489804, synthete_average_primary_balance=-2.552048892199754, higher_band=Country(name='New Zealand', abbreviation='NZL', average_gdp_per_capita=29305.265755102042, average_gdp_growth_rate=2.526530612244898, average_primary_balance=-0.8704545454545454, synthete_average_gdp_per_capita=30299.723532404852, synthete_average_gdp_growth_rate=1.8828514739229023, synthete_average_primary_balance=-2.7067565539150413, higher_band=Country(name='Germany', abbreviation='DEU', average_gdp_per_capita=37281.10210204083, average_gdp_growth_rate=1.5448979591836736, average_primary_balance=-1.8526315789473686, synthete_average_gdp_per_capita=43011.94 ...
#  Country(name='Uganda', abbreviation='UGA', average_gdp_per_capita=1814.168612244898, average_gdp_growth_rate=5.50204081632653, average_primary_balance=-2.36875, synthete_average_gdp_per_capita=1911.3068743842366, synthete_average_gdp_growth_rate=3.2932397959183675, synthete_average_primary_balance=-2.4900994413925104, higher_band=Country(name='Zambia', abbreviation='ZMB', average_gdp_per_capita=2579.0008571428566, average_gdp_growth_rate=3.4714285714285706, average_primary_balance=-4.024137931034483, synthete_average_gdp_per_capita=2771.8661608451075, synthete_average_gdp_growth_rate=4.452434098639455, synthete_average_primary_balance=-2.5920057697667027, higher_band=Country(name='Honduras', abbreviation='HND', average_gdp_per_capita=3759.2878367346943, average_gdp_growth_rate=3.355102040816326, average_primary_balance=-1.6205128205128203, synthete_average_gdp_per_capita=3638.8891183136043, synthete_average_gdp_growth_rate=3.3160425134966265, synthete_average_primary_balance=-1.1905486444404687, higher_band=Country(name='Nicaragua', abbreviation='NIC', average_gdp_per_capita=4843.064171428572, average_gdp_growth_rate=2.4510204081632647, average_primary_balance=-0.02068965517241379, synthete_average_gdp_per_capita=5198.652038478931, synthete_average_gdp_growth_rate=3.479742639741568, synthete_average_primary_balance=-2.5729424385575905, higher_band=Country(name='Belize', abbreviation='BLZ', average_gdp_per_capita=7343.887469387754, average_gdp_growth_rate=4.622448979591836, average_primary_balance=-2.7848484848484856, synthete_average_gdp_per_capita=6865.056762399774, synthete_average_gdp_growth_rate=3.7631511815252416, synthete_average_primary_balance=-2.2113968543261673, higher_band=Country(name='Paraguay', abbreviation='PRY', average_gdp_per_capita=9026.938816326532, average_gdp_growth_rate=3.3265306122448974, average_primary_balance=0.6959183673469383, synthete_average_gdp_per_capita=9282.759138670785, synthete_average_gdp_growth_rate=3.620985499462944, synthete_average_primary_balance=0.22304500280539802, higher_band=Country(name='Botswana', abbreviation='BWA', average_gdp_per_capita=11087.832183673469, average_gdp_growth_rate=5.353061224489798, average_primary_balance=-0.45333333333333337, synthete_average_gdp_per_capita=11330.133538409013, synthete_average_gdp_growth_rate=1.6795163584637265, synthete_average_primary_balance=-2.8879965049680347, higher_band=Country(name='Palau', abbreviation='PLW', average_gdp_per_capita=13966.251310344825, average_gdp_growth_rate=1.157142857142857, average_primary_balance=-1.8413793103448284, synthete_average_gdp_per_capita=14282.950425990244, synthete_average_gdp_growth_rate=4.2189888724306925, synthete_average_primary_balance=-1.4830747953193213, higher_band=Country(name='Panama', abbreviation='PAN', average_gdp_per_capita=17702.194020408162, average_gdp_growth_rate=4.616326530612246, average_primary_balance=-2.168571428571428, synthete_average_gdp_per_capita=18583.544490182285, synthete_average_gdp_growth_rate=3.4911478687219564, synthete_average_primary_balance=-11.282930363356295, higher_band=Country(name='Croatia', abbreviation='HRV', average_gdp_per_capita=24082.030891891885, average_gdp_growth_rate=2.4444444444444446, average_primary_balance=-3.5135135135135136, synthete_average_gdp_per_capita=23919.986754136793, synthete_average_gdp_growth_rate=3.493041383219955, synthete_average_primary_balance=-2.744356259443734, higher_band=Country(name='Slovenia', abbreviation='SVN', average_gdp_per_capita=31278.26913513514, average_gdp_growth_rate=2.8055555555555554, average_primary_balance=-3.244117647058823, synthete_average_gdp_per_capita=30810.294399751794, synthete_average_gdp_growth_rate=1.9526537698412696, synthete_average_primary_balance=-1.720719138949055, higher_band=Country(name='Sweden', abbreviation='SWE', average_gdp_per_capita=37389.03408163264, average_gdp_growth_rate=2.265306122448979, average_primary_balance=-0.8551020408163265, synthete_average_gdp_per_capita=44986.64010 ...
#  Country(name='Tanzania', abbreviation='TZA', average_gdp_per_capita=1852.82, average_gdp_growth_rate=5.142857142857143, average_primary_balance=-2.286842105263158, synthete_average_gdp_per_capita=1945.793914562808, synthete_average_gdp_growth_rate=3.3788218065003783, synthete_average_primary_balance=-3.2585233357347305, higher_band=Country(name='São Tomé and Príncipe', abbreviation='STP', average_gdp_per_capita=2607.6575714285723, average_gdp_growth_rate=2.0755102040816324, average_primary_balance=3.348275862068966, synthete_average_gdp_per_capita=2815.8443414297735, synthete_average_gdp_growth_rate=4.03422395273899, synthete_average_primary_balance=-2.577486899718684, higher_band=Country(name='Kyrgyz Republic', abbreviation='KGZ', average_gdp_per_capita=3803.1804324324326, average_gdp_growth_rate=2.8, average_primary_balance=-4.458823529411765, synthete_average_gdp_per_capita=3733.0331024972775, synthete_average_gdp_growth_rate=3.43578290965509, synthete_average_primary_balance=-1.0055948267064783, higher_band=Country(name='Cabo Verde', abbreviation='CPV', average_gdp_per_capita=4881.653204081634, average_gdp_growth_rate=5.006122448979592, average_primary_balance=-6.025714285714285, synthete_average_gdp_per_capita=5425.469760417706, synthete_average_gdp_growth_rate=4.103977333619119, synthete_average_primary_balance=-3.3396837919156943, higher_band=Country(name='Indonesia', abbreviation='IDN', average_gdp_per_capita=7728.969571428572, average_gdp_growth_rate=5.253061224489795, average_primary_balance=-1.530555555555556, synthete_average_gdp_per_capita=6963.60978944059, synthete_average_gdp_growth_rate=3.317232814178303, synthete_average_primary_balance=-3.48263932650763, higher_band=Country(name='Egypt', abbreviation='EGY', average_gdp_per_capita=9036.139714285715, average_gdp_growth_rate=4.618367346938776, average_primary_balance=-7.293333333333334, synthete_average_gdp_per_capita=9453.897985408163, synthete_average_gdp_growth_rate=3.7674744897959194, synthete_average_primary_balance=0.20025323059412153, higher_band=Country(name='Thailand', abbreviation='THA', average_gdp_per_capita=11363.962857142857, average_gdp_growth_rate=4.522448979591835, average_primary_balance=-1.476470588235294, synthete_average_gdp_per_capita=11471.537525719321, synthete_average_gdp_growth_rate=1.6135426285462275, synthete_average_primary_balance=-3.172407480896868, higher_band=Country(name='Belarus', abbreviation='BLR', average_gdp_per_capita=14012.546102564102, average_gdp_growth_rate=2.2191489361702126, average_primary_balance=-2.7964285714285717, synthete_average_gdp_per_capita=14621.807462967776, synthete_average_gdp_growth_rate=4.805840419501132, synthete_average_primary_balance=-2.0271490658763502, higher_band=Country(name='Malaysia', abbreviation='MYS', average_gdp_per_capita=18326.49906122449, average_gdp_growth_rate=5.3775510204081645, average_primary_balance=-2.3564102564102565, synthete_average_gdp_per_capita=18993.628951389182, synthete_average_gdp_growth_rate=3.6513519503546097, synthete_average_primary_balance=-10.894398308748013, higher_band=Country(name='Portugal', abbreviation='PRT', average_gdp_per_capita=24418.989816326528, average_gdp_growth_rate=2.13469387755102, average_primary_balance=-4.4255813953488365, synthete_average_gdp_per_capita=24394.75586770118, synthete_average_gdp_growth_rate=3.246740362811792, synthete_average_primary_balance=-3.166510454455072, higher_band=Country(name='Japan', abbreviation='JPN', average_gdp_per_capita=31882.091857142845, average_gdp_growth_rate=1.6102040816326526, average_primary_balance=-4.2346938775510194, synthete_average_gdp_per_capita=31274.340166950118, synthete_average_gdp_growth_rate=2.077251275510204, synthete_average_primary_balance=-1.7877561597560596, higher_band=Country(name='Iceland', abbreviation='ISL', average_gdp_per_capita=37896.31742857143, average_gdp_growth_rate=2.8285714285714283, average_primary_balance=-1.3061224489795922, synthete_average_gdp_per_capita=47381.1995553 ...
#  Country(name='Guinea', abbreviation='GIN', average_gdp_per_capita=1868.8262051282054, average_gdp_growth_rate=4.226530612244899, average_primary_balance=-1.648717948717949, synthete_average_gdp_per_capita=1983.1716890264395, synthete_average_gdp_growth_rate=3.5533518816883483, synthete_average_primary_balance=-3.5359295585588693, higher_band=Country(name='Yemen', abbreviation='YEM', average_gdp_per_capita=2658.225358974358, average_gdp_growth_rate=1.9105263157894736, average_primary_balance=-4.223076923076923, synthete_average_gdp_per_capita=2858.7356824693143, synthete_average_gdp_growth_rate=3.353183794740307, synthete_average_primary_balance=-1.7602570225704564, higher_band=Country(name='Marshall Islands', abbreviation='MHL', average_gdp_per_capita=3837.724687499999, average_gdp_growth_rate=1.512903225806452, average_primary_balance=1.9093749999999996, synthete_average_gdp_per_capita=3805.9114904813177, synthete_average_gdp_growth_rate=3.8664739119867026, synthete_average_primary_balance=-1.810477794313584, higher_band=Country(name='Mauritania', abbreviation='MRT', average_gdp_per_capita=4915.135358974359, average_gdp_growth_rate=3.586842105263158, average_primary_balance=-0.11199999999999996, synthete_average_gdp_per_capita=5673.7471038506, synthete_average_gdp_growth_rate=4.580089697169191, synthete_average_primary_balance=-0.25622844739544126, higher_band=Country(name='Nauru', abbreviation='NRU', average_gdp_per_capita=7937.935719999998, average_gdp_growth_rate=5.250000000000001, average_primary_balance=16.52, synthete_average_gdp_per_capita=7122.6380201355705, synthete_average_gdp_growth_rate=2.8960459183673466, synthete_average_primary_balance=-2.671653901087462, higher_band=Country(name='Moldova', abbreviation='MDA', average_gdp_per_capita=9142.557702702703, average_gdp_growth_rate=0.5631578947368405, average_primary_balance=-2.4147058823529406, synthete_average_gdp_per_capita=9579.230669081633, synthete_average_gdp_growth_rate=3.9100765306122454, synthete_average_primary_balance=-0.17386252284544645, higher_band=Country(name='Dominican Republic', abbreviation='DOM', average_gdp_per_capita=11447.792448979593, average_gdp_growth_rate=4.616326530612246, average_primary_balance=-2.6093749999999996, synthete_average_gdp_per_capita=11634.401512640701, synthete_average_gdp_growth_rate=2.071188603602917, synthete_average_primary_balance=-2.782988824840281, higher_band=Country(name='Mauritius', abbreviation='MUS', average_gdp_per_capita=14077.488306122452, average_gdp_growth_rate=4.0265306122448985, average_primary_balance=-4.1241379310344835, synthete_average_gdp_per_capita=14782.424911890677, synthete_average_gdp_growth_rate=3.9592077664399095, synthete_average_primary_balance=-2.644877003205128, higher_band=Country(name='Romania', abbreviation='ROU', average_gdp_per_capita=18396.891999999996, average_gdp_growth_rate=2.0816326530612246, average_primary_balance=-3.7256410256410253, synthete_average_gdp_per_capita=19397.76318546608, synthete_average_gdp_growth_rate=4.048922902494331, synthete_average_primary_balance=-10.701192958990243, higher_band=Country(name='Libya', abbreviation='LBY', average_gdp_per_capita=24779.60053061225, average_gdp_growth_rate=0.9387755102040818, average_primary_balance=3.874358974358975, synthete_average_gdp_per_capita=24995.723448098877, synthete_average_gdp_growth_rate=2.8045654246547107, synthete_average_primary_balance=-2.778048121393347, higher_band=Country(name='Czech Republic', abbreviation='CZE', average_gdp_per_capita=32591.016735294113, average_gdp_growth_rate=2.348484848484849, average_primary_balance=-3.0411764705882347, synthete_average_gdp_per_capita=31781.94135827665, synthete_average_gdp_growth_rate=2.480822704081633, synthete_average_primary_balance=-0.8187558838090387, higher_band=Country(name='Austria', abbreviation='AUT', average_gdp_per_capita=38619.52628571429, average_gdp_growth_rate=1.8, average_primary_balance=-2.6878048780487807, synthete_average_gdp_per_capita=49473.418 ...
# ...
#  Country(name='Denmark', abbreviation='DNK', average_gdp_per_capita=40942.78018367348, average_gdp_growth_rate=1.7632653061224488, average_primary_balance=-0.4857142857142861, synthete_average_gdp_per_capita=58787.59141581632, synthete_average_gdp_growth_rate=3.7017580287929124, synthete_average_primary_balance=0.8718325934532812, higher_band=Country(name='Macao SAR', abbreviation='MAC', average_gdp_per_capita=99724.07860714286, average_gdp_growth_rate=7.833333333333333, average_primary_balance=8.775, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None), lower_band=Country(name='Taiwan Province of China', abbreviation='TWN', average_gdp_per_capita=33156.34328571428, average_gdp_growth_rate=5.144897959183673, average_primary_balance=-3.3653061224489793, synthete_average_gdp_per_capita=33698.49838893057, synthete_average_gdp_growth_rate=3.2876249420222634, synthete_average_primary_balance=-1.3202982396701322, higher_band=..., lower_band=Country(name='Korea, Republic of', abbreviation='KOR', average_gdp_per_capita=26251.172469387762, average_gdp_growth_rate=5.369387755102041, average_primary_balance=1.026470588235294, synthete_average_gdp_per_capita=26381.61796560178, synthete_average_gdp_growth_rate=2.832825061842919, synthete_average_primary_balance=-2.7901476402980183, higher_band=..., lower_band=Country(name='Kazakhstan', abbreviation='KAZ', average_gdp_per_capita=19595.638540540538, average_gdp_growth_rate=3.591666666666667, average_primary_balance=0.5407407407407405, synthete_average_gdp_per_capita=20560.573103174607, synthete_average_gdp_growth_rate=3.046639030612245, synthete_average_primary_balance=-1.6148908006130485, higher_band=..., lower_band=Country(name='Maldives', abbreviation='MDV', average_gdp_per_capita=15072.05679591837, average_gdp_growth_rate=7.408163265306124, average_primary_balance=-7.202564102564102, synthete_average_gdp_per_capita=15356.274127196713, synthete_average_gdp_growth_rate=3.246795551553955, synthete_average_primary_balance=-2.5930990106090044, higher_band=..., lower_band=Country(name='Venezuela', abbreviation='VEN', average_gdp_per_capita=11717.805244444442, average_gdp_growth_rate=-0.7200000000000001, average_primary_balance=-4.817142857142857, synthete_average_gdp_per_capita=12318.201924769863, synthete_average_gdp_growth_rate=5.112748015873016, synthete_average_primary_balance=-10.571062582999222, higher_band=..., lower_band=Country(name='Armenia', abbreviation='ARM', average_gdp_per_capita=9633.841918918919, average_gdp_growth_rate=5.330555555555555, average_primary_balance=-3.033333333333333, synthete_average_gdp_per_capita=9864.919606029873, synthete_average_gdp_growth_rate=3.604085585988781, synthete_average_primary_balance=-2.620091899026008, higher_band=..., lower_band=Country(name='Jordan', abbreviation='JOR', average_gdp_per_capita=7982.704020408163, average_gdp_growth_rate=3.8, average_primary_balance=-5.672727272727273, synthete_average_gdp_per_capita=7585.1073920116405, synthete_average_gdp_growth_rate=3.3503380091960913, synthete_average_primary_balance=-2.4790686407518545, higher_band=..., lower_band=Country(name='Philippines', abbreviation='PHL', average_gdp_per_capita=5674.241367346938, average_gdp_growth_rate=4.0265306122448985, average_primary_balance=-1.795, synthete_average_gdp_per_capita=6031.288873817373, synthete_average_gdp_growth_rate=3.793320354457573, synthete_average_primary_balance=-0.24758886153169302, higher_band=..., lower_band=Country(name='Lao P.D.R.', abbreviation='LAO', average_gdp_per_capita=4075.509204081632, average_gdp_growth_rate=5.961224489795921, average_primary_balance=-3.1172413793103457, synthete_average_gdp_per_capita=4104.866893903064, synthete_average_gdp_growth_rate=3.1132590295424976, synthete_average_primary_balance=-4.840121055100834, higher_band=..., lower_band=Country(name='Cambodia', abbreviation='KHM', average_gdp_per_capita=2868.0445, av ...
#  Country(name='Bahrain', abbreviation='BHR', average_gdp_per_capita=43261.594183673486, average_gdp_growth_rate=3.808163265306121, average_primary_balance=-5.525641025641025, synthete_average_gdp_per_capita=62658.28046008839, synthete_average_gdp_growth_rate=3.9532312925170063, synthete_average_primary_balance=1.794171266684812, higher_band=Country(name='Qatar', abbreviation='QAT', average_gdp_per_capita=99992.85912244898, average_gdp_growth_rate=4.9755102040816315, average_primary_balance=5.21794871794872, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None), lower_band=Country(name='France', abbreviation='FRA', average_gdp_per_capita=34118.23502040816, average_gdp_growth_rate=1.6877551020408164, average_primary_balance=-3.659183673469388, synthete_average_gdp_per_capita=34543.836192502014, synthete_average_gdp_growth_rate=3.1332882073283854, synthete_average_primary_balance=-2.3380304591995955, higher_band=..., lower_band=Country(name='Estonia', abbreviation='EST', average_gdp_per_capita=27347.208166666667, average_gdp_growth_rate=3.4371428571428577, average_primary_balance=-0.8117647058823529, synthete_average_gdp_per_capita=26660.75068367347, synthete_average_gdp_growth_rate=3.1681122448979595, synthete_average_primary_balance=-3.3490536332507546, higher_band=..., lower_band=Country(name='Seychelles', abbreviation='SYC', average_gdp_per_capita=19758.895714285718, average_gdp_growth_rate=3.8795918367346935, average_primary_balance=-1.7413043478260868, synthete_average_gdp_per_capita=20943.225470946712, synthete_average_gdp_growth_rate=2.7122512755102046, synthete_average_primary_balance=-1.5565857478227023, higher_band=..., lower_band=Country(name='Mexico', abbreviation='MEX', average_gdp_per_capita=15422.519367346937, average_gdp_growth_rate=2.2346938775510203, average_primary_balance=-2.674358974358974, synthete_average_gdp_per_capita=15648.46759409014, synthete_average_gdp_growth_rate=4.0212343270641595, synthete_average_primary_balance=-2.198042273867485, higher_band=..., lower_band=Country(name='Bosnia and Herzegovina', abbreviation='BIH', average_gdp_per_capita=11882.677727272725, average_gdp_growth_rate=6.48529411764706, average_primary_balance=-1.2129032258064514, synthete_average_gdp_per_capita=12577.146241027445, synthete_average_gdp_growth_rate=4.637244897959183, synthete_average_primary_balance=-10.269327392901964, higher_band=..., lower_band=Country(name='Algeria', abbreviation='DZA', average_gdp_per_capita=10082.481857142857, average_gdp_growth_rate=2.446938775510205, average_primary_balance=-2.607692307692308, synthete_average_gdp_per_capita=9968.101604411326, synthete_average_gdp_growth_rate=3.696635105796704, synthete_average_primary_balance=-2.102467659186546, higher_band=..., lower_band=Country(name='Ecuador', abbreviation='ECU', average_gdp_per_capita=8117.3555306122435, average_gdp_growth_rate=2.616326530612245, average_primary_balance=-2.1382352941176466, synthete_average_gdp_per_capita=7740.748952132986, synthete_average_gdp_growth_rate=3.89014735398664, synthete_average_primary_balance=-2.6605877772526085, higher_band=..., lower_band=Country(name='Vietnam', abbreviation='VNM', average_gdp_per_capita=5701.915530612245, average_gdp_growth_rate=6.328571428571429, average_primary_balance=-2.064516129032258, synthete_average_gdp_per_capita=6064.309074633699, synthete_average_gdp_growth_rate=2.998868823845328, synthete_average_primary_balance=-2.3252131008826056, higher_band=..., lower_band=Country(name='Nigeria', abbreviation='NGA', average_gdp_per_capita=4087.072025641026, average_gdp_growth_rate=4.221052631578947, average_primary_balance=-1.8153846153846154, synthete_average_gdp_per_capita=4247.88448040882, synthete_average_gdp_growth_rate=3.1261904761904766, synthete_average_primary_balance=-5.1605153584639085, higher_band=..., lower_band=Country(name='Timor-Leste', abbreviation='TLS', average_gdp_per_capi ...
#  Country(name='United States', abbreviation='USA', average_gdp_per_capita=44546.354489795915, average_gdp_growth_rate=2.4938775510204074, average_primary_balance=-6.253571428571427, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Norway', abbreviation='NOR', average_gdp_per_capita=50987.72759183673, average_gdp_growth_rate=2.306122448979592, average_primary_balance=8.169387755102042, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Switzerland', abbreviation='CHE', average_gdp_per_capita=51593.013489795914, average_gdp_growth_rate=1.814285714285715, average_primary_balance=-0.2652173913043479, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Saudi Arabia', abbreviation='SAU', average_gdp_per_capita=51789.33397959183, average_gdp_growth_rate=2.3816326530612244, average_primary_balance=-0.028947368421052305, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Ireland', abbreviation='IRL', average_gdp_per_capita=52672.57328571429, average_gdp_growth_rate=4.908163265306122, average_primary_balance=-1.9794117647058826, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Kuwait', abbreviation='KWT', average_gdp_per_capita=54813.05813888888, average_gdp_growth_rate=3.8638297872340424, average_primary_balance=8.381818181818183, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Andorra', abbreviation='AND', average_gdp_per_capita=59763.94268421053, average_gdp_growth_rate=1.6714285714285713, average_primary_balance=1.285714285714286, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Singapore', abbreviation='SGP', average_gdp_per_capita=64256.24314285713, average_gdp_growth_rate=5.626530612244899, average_primary_balance=3.2692307692307705, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='San Marino', abbreviation='SMR', average_gdp_per_capita=70145.93068000002, average_gdp_growth_rate=1.380645161290322, average_primary_balance=-3.4000000000000004, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Brunei Darussalam', abbreviation='BRN', average_gdp_per_capita=70276.56024999998, average_gdp_growth_rate=1.2093023255813955, average_primary_balance=-1.2954545454545459, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Luxembourg', abbreviation='LUX', average_gdp_per_capita=79772.91446938775, average_gdp_growth_rate=3.5653061224489804, average_primary_balance=1.1029411764705885, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='United Arab Emirates', abbreviation='ARE', average_gdp_per_capita=84844.37330612243, average_gdp_growth_rate=3.6204081632653065, average_primary_balance=4.113157894736842, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Macao SAR', abbreviation='MAC', average_gdp_per_capita=99724.07860714286, average_gdp_growth_rate=7.833333333333333, average_primary_balance=8.775, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None),
#  Country(name='Qatar', abbreviation='QAT', average_gdp_per_capita=99992.85912244898, average_gdp_growth_rate=4.9755102040816315, average_primary_balance=5.21794871794872, synthete_average_gdp_per_capita=None, synthete_average_gdp_growth_rate=None, synthete_average_primary_balance=None, higher_band=None, lower_band=None)]

# %% [markdown]
# # POLARS DRAFT

# %%
df = pl.from_dicts(
            data=[{"Country": country, **gdp_per_capita[country]} for country in gdp_per_capita],
            schema=[
                "Country",
                "1980",
                "1981",
                "1982",
                "1983",
                "1984",
                "1985",
                "1986",
                "1987",
                "1988",
                "1989",
                "1990",
                "1991",
                "1992",
                "1993",
                "1994",
                "1995",
                "1996",
                "1997",
                "1998",
                "1999",
                "2000",
                "2001",
                "2002",
                "2003",
                "2004",
                "2005",
                "2006",
                "2007",
                "2008",
                "2009",
                "2010",
                "2011",
                "2012",
                "2013",
                "2014",
                "2015",
                "2016",
                "2017",
                "2018",
                "2019",
                "2020",
                "2021",
                "2022",
                "2023",
            ],
        ).melt(
            id_vars="Country",
            value_vars=cs.numeric(),
            variable_name='Year',
            value_name='GDP per cap',
        ).group_by("Country", maintain_order=True).agg(pl.col("GDP per cap").mean()).sort("GDP per cap")

# %%
df

# %% [markdown]
# # Clustering Draft

# %%
import requests
import numpy as np
import polars as pl
import polars.selectors as cs
import sklearn.cluster as cluster
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.palettes import Category10
output_notebook()

# %%
indicators = requests.get(
        "https://www.imf.org/external/datamapper/api/v1/indicators"
    ).json()["indicators"]

# %%
indicators

# %%
average_gdp_per_capita = {country: sum(gdp_values.values()) / len(gdp_values) for country, gdp_values in gdp_per_capita.items()}

# %%
growth_rate = requests.get(
        "https://www.imf.org/external/datamapper/api/v1/NGDP_RPCH"
    ).json()['values']['NGDP_RPCH']

# %%
average_growth_rate = {country: sum(growth_rates.values()) / len(growth_rates) for country, growth_rates in growth_rate.items()}

# %%
average_gdp_per_capitas = list(average_gdp_per_capita.values())
average_growth_rates = list(average_growth_rate.values())
features = np.array(list(zip(average_gdp_per_capitas, average_growth_rates)))

# %%
X = np.array(features)

# %%
kmeans = cluster.KMeans(n_clusters=15, algorithm='elkan')  # Adjust the number of clusters as needed
kmeans.fit(X)

# %%
labels = kmeans.labels_

# %%
p = figure(output_backend="webgl", title='test', width=400, height=400)
colors = np.array([x for x in ('#00f', '#0f0', '#f00', '#0ff', '#f0f', '#ff0')])
colors = np.hstack([colors] * 20)
p = figure(title='K-Means Clustering', x_axis_label='GDP', y_axis_label='Growth Rate')
p.scatter(X[:, 0], X[:, 1], color=colors[labels].tolist(), legend_field='Cluster', size=10)
show(p)

# %%
primary_balance = requests.get(
        "https://www.imf.org/external/datamapper/api/v1/GGXONLB_G01_GDP_PT"
    ).json()['values']['GGXONLB_G01_GDP_PT']

# %%
all_countries = requests.get(
        "https://www.imf.org/external/datamapper/api/v1/countries"
    ).json()

# %%
all_countries

# %%
mapping_countries = {k : v["label"] for k, v in all_countries["countries"].items()}

# %%
mapping_countries

# %%
formatted_gdp_per_capita = {mapping_countries.get(k, None): v for k, v in gdp_per_capita.items() if mapping_countries.get(k, None)}

# %%
formatted_growth_rate = {mapping_countries.get(k, None): v for k, v in growth_rate.items() if mapping_countries.get(k, None)}

# %%
formatted_primary_balance = {mapping_countries.get(k, None): v for k, v in primary_balance.items() if mapping_countries.get(k, None)}

# %%
gdp_per_capita_df = pl.from_dicts(
    data=[{"Country": country, **formatted_gdp_per_capita[country]} for country in formatted_gdp_per_capita],
    schema=[
        "Country",
        # "1980",
        # "1981",
        # "1982",
        # "1983",
        # "1984",
        # "1985",
        # "1986",
        # "1987",
        # "1988",
        # "1989",
        "1990",
        "1991",
        "1992",
        "1993",
        "1994",
        "1995",
        "1996",
        "1997",
        "1998",
        "1999",
        "2000",
        "2001",
        "2002",
        "2003",
        "2004",
        "2005",
        "2006",
        "2007",
        "2008",
        "2009",
        "2010",
        "2011",
        "2012",
        "2013",
        "2014",
        "2015",
        "2016",
        "2017",
        "2018",
        "2019",
        # "2020",
        # "2021",
        # "2022",
        # "2023",
    ],
)

# %%
growth_rate_df = pl.from_dicts(
    data=[{"Country": country, **formatted_growth_rate[country]} for country in formatted_growth_rate],
    schema=[
        "Country",
        "1980",
        "1981",
        "1982",
        "1983",
        "1984",
        "1985",
        "1986",
        "1987",
        "1988",
        "1989",
        "1990",
        "1991",
        "1992",
        "1993",
        "1994",
        "1995",
        "1996",
        "1997",
        "1998",
        "1999",
        "2000",
        "2001",
        "2002",
        "2003",
        "2004",
        "2005",
        "2006",
        "2007",
        "2008",
        "2009",
        "2010",
        "2011",
        "2012",
        "2013",
        "2014",
        "2015",
        "2016",
        "2017",
        "2018",
        "2019",
        "2020",
        "2021",
        "2022",
        "2023",
    ],
)

# %%
primary_balance_df = pl.from_dicts(
    data=[{"Country": country, **formatted_primary_balance[country]} for country in formatted_primary_balance],
    schema=[
        "Country",
        "1980",
        "1981",
        "1982",
        "1983",
        "1984",
        "1985",
        "1986",
        "1987",
        "1988",
        "1989",
        "1990",
        "1991",
        "1992",
        "1993",
        "1994",
        "1995",
        "1996",
        "1997",
        "1998",
        "1999",
        "2000",
        "2001",
        "2002",
        "2003",
        "2004",
        "2005",
        "2006",
        "2007",
        "2008",
        "2009",
        "2010",
        "2011",
        "2012",
        "2013",
        "2014",
        "2015",
        "2016",
        "2017",
        "2018",
        "2019",
        "2020",
        "2021",
        "2022",
        "2023",
    ],
)

# %%
gdp_per_capita_df

# %%
growth_rate_df

# %%
primary_balance_df

# %%
gdp_per_capita_df.melt(
            id_vars="Country",
            value_vars=cs.numeric()
).group_by('Country', maintain_order=True).agg(pl.col("value")
.mean()).sort("value").filter(pl.col("Country") == "Jamaica")

# %%
growth_rate_df.melt(
            id_vars="Country",
            value_vars=cs.numeric()
).group_by('Country', maintain_order=True).agg(pl.col("value")
.mean()).sort("value").filter(pl.col("Country") == "Jamaica")

# %%
primary_balance_df.melt(
            id_vars="Country",
            value_vars=cs.numeric()
).group_by('Country', maintain_order=True).agg(pl.col("value")
.mean()).sort("value").filter(pl.col("Country") == "Jamaica")

# %%
pl.Config(tbl_rows=-1)

# %%
cluster.KMeans([4,
